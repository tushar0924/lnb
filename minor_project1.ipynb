# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
books=pd.read_csv(r'D:/books.csv')

# %%
books_df=pd.DataFrame(books)
books_df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#              isbn        isbn13 language_code    num_pages  ratings_count  \
# 0       439785960  9.780000e+12           eng          652        2095690
# 1       439358078  9.780000e+12           eng          870        2153167
# 2       439554896  9.780000e+12           eng          352           6333
# 3      043965548X  9.780000e+12           eng          435        2339585
# 4       439682584  9.780000e+12           eng         2690          41428
# ...           ...           ...           ...          ...            ...
# 11118  1560254416  9.780000e+12           eng          512            156
# 11119   140110879  9.780000e+12           eng          635            783
# 11120   140131965  9.780000e+12           eng          415            820
# 11121    60878827  9.780000e+12           eng          434            769
# 11122  8497646983  9.790000e+12           spa          272            113
#
#        text_reviews_count publication_date        publisher
# 0                   27591        9-16-2006  Scholastic Inc.
# 1                   29221       09-01-2004  Scholastic Inc.
# 2                     244       11-01-2003       Scholastic
# 3                   36325       05-01-2004  Scholastic Inc.
# 4                     164        9-13-2004       Scholastic
# ...                   ...              ...              ...
# 11118                  20       12-21-2004    Da Capo Press
# 11119                  56       12-01-1988    Penguin Books
# 11120                  95       08-01-1993    Penguin Books
# 11121                 139        2-27-2007             Ecco
# 11122                  12        5-28-2006    Edimat Libros
#
# [11123 rows x 12 columns]

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  float64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.0+ MB

# %%
books_df.set_index('bookID',inplace=True)

# %%
books_df
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                   ...
# 45631    Expelled from Eden: A William T. Vollmann Reader
# 45633                         You Bright and Risen Angels
# 45634                     The Ice-Shirt (Seven Dreams #1)
# 45639                                         Poor People
# 45641                         Las aventuras de Tom Sawyer
#
#                                                   authors  average_rating  \
# bookID
# 1                              J.K. Rowling/Mary GrandPré            4.57
# 2                              J.K. Rowling/Mary GrandPré            4.49
# 4                                            J.K. Rowling            4.42
# 5                              J.K. Rowling/Mary GrandPré            4.56
# 8                              J.K. Rowling/Mary GrandPré            4.78
# ...                                                   ...             ...
# 45631   William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 45633                                 William T. Vollmann            4.08
# 45634                                 William T. Vollmann            3.96
# 45639                                 William T. Vollmann            3.72
# 45641                                          Mark Twain            3.91
#
#               isbn        isbn13 language_code    num_pages  ratings_count  \
# bookID
# 1        439785960  9.780000e+12           eng          652        2095690
# 2        439358078  9.780000e+12           eng          870        2153167
# 4        439554896  9.780000e+12           eng          352           6333
# 5       043965548X  9.780000e+12           eng          435        2339585
# 8        439682584  9.780000e+12           eng         2690          41428
# ...            ...           ...           ...          ...            ...
# 45631   1560254416  9.780000e+12           eng          512            156
# 45633    140110879  9.780000e+12           eng          635            783
# 45634    140131965  9.780000e+12           eng          415            820
# 45639     60878827  9.780000e+12           eng          434            769
# 45641   8497646983  9.790000e+12           spa          272            113
#
#         text_reviews_count publication_date        publisher
# bookID
# 1                    27591        9/16/2006  Scholastic Inc.
# 2                    29221       09-01-2004  Scholastic Inc.
# 4                      244       11-01-2003       Scholastic
# 5                    36325       05-01-2004  Scholastic Inc.
# 8                      164        9/13/2004       Scholastic
# ...                    ...              ...              ...
# 45631                   20       12/21/2004    Da Capo Press
# 45633                   56       12-01-1988    Penguin Books
# 45634                   95       08-01-1993    Penguin Books
# 45639                  139        2/27/2007             Ecco
# 45641                   12        5/28/2006    Edimat Libros
#
# [11123 rows x 11 columns]

# %%
books_df.drop_duplicates(inplace=True)

# %%
books_df
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                   ...
# 45631    Expelled from Eden: A William T. Vollmann Reader
# 45633                         You Bright and Risen Angels
# 45634                     The Ice-Shirt (Seven Dreams #1)
# 45639                                         Poor People
# 45641                         Las aventuras de Tom Sawyer
#
#                                                   authors  average_rating  \
# bookID
# 1                              J.K. Rowling/Mary GrandPré            4.57
# 2                              J.K. Rowling/Mary GrandPré            4.49
# 4                                            J.K. Rowling            4.42
# 5                              J.K. Rowling/Mary GrandPré            4.56
# 8                              J.K. Rowling/Mary GrandPré            4.78
# ...                                                   ...             ...
# 45631   William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 45633                                 William T. Vollmann            4.08
# 45634                                 William T. Vollmann            3.96
# 45639                                 William T. Vollmann            3.72
# 45641                                          Mark Twain            3.91
#
#               isbn        isbn13 language_code    num_pages  ratings_count  \
# bookID
# 1        439785960  9.780000e+12           eng          652        2095690
# 2        439358078  9.780000e+12           eng          870        2153167
# 4        439554896  9.780000e+12           eng          352           6333
# 5       043965548X  9.780000e+12           eng          435        2339585
# 8        439682584  9.780000e+12           eng         2690          41428
# ...            ...           ...           ...          ...            ...
# 45631   1560254416  9.780000e+12           eng          512            156
# 45633    140110879  9.780000e+12           eng          635            783
# 45634    140131965  9.780000e+12           eng          415            820
# 45639     60878827  9.780000e+12           eng          434            769
# 45641   8497646983  9.790000e+12           spa          272            113
#
#         text_reviews_count publication_date        publisher
# bookID
# 1                    27591        9/16/2006  Scholastic Inc.
# 2                    29221       09-01-2004  Scholastic Inc.
# 4                      244       11-01-2003       Scholastic
# 5                    36325       05-01-2004  Scholastic Inc.
# 8                      164        9/13/2004       Scholastic
# ...                    ...              ...              ...
# 45631                   20       12/21/2004    Da Capo Press
# 45633                   56       12-01-1988    Penguin Books
# 45634                   95       08-01-1993    Penguin Books
# 45639                  139        2/27/2007             Ecco
# 45641                   12        5/28/2006    Edimat Libros
#
# [11123 rows x 11 columns]

# %%
books_df.dropna(axis=1,inplace=True)

# %%
books_df
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                   ...
# 45631    Expelled from Eden: A William T. Vollmann Reader
# 45633                         You Bright and Risen Angels
# 45634                     The Ice-Shirt (Seven Dreams #1)
# 45639                                         Poor People
# 45641                         Las aventuras de Tom Sawyer
#
#                                                   authors  average_rating  \
# bookID
# 1                              J.K. Rowling/Mary GrandPré            4.57
# 2                              J.K. Rowling/Mary GrandPré            4.49
# 4                                            J.K. Rowling            4.42
# 5                              J.K. Rowling/Mary GrandPré            4.56
# 8                              J.K. Rowling/Mary GrandPré            4.78
# ...                                                   ...             ...
# 45631   William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 45633                                 William T. Vollmann            4.08
# 45634                                 William T. Vollmann            3.96
# 45639                                 William T. Vollmann            3.72
# 45641                                          Mark Twain            3.91
#
#               isbn        isbn13 language_code    num_pages  ratings_count  \
# bookID
# 1        439785960  9.780000e+12           eng          652        2095690
# 2        439358078  9.780000e+12           eng          870        2153167
# 4        439554896  9.780000e+12           eng          352           6333
# 5       043965548X  9.780000e+12           eng          435        2339585
# 8        439682584  9.780000e+12           eng         2690          41428
# ...            ...           ...           ...          ...            ...
# 45631   1560254416  9.780000e+12           eng          512            156
# 45633    140110879  9.780000e+12           eng          635            783
# 45634    140131965  9.780000e+12           eng          415            820
# 45639     60878827  9.780000e+12           eng          434            769
# 45641   8497646983  9.790000e+12           spa          272            113
#
#         text_reviews_count publication_date        publisher
# bookID
# 1                    27591        9/16/2006  Scholastic Inc.
# 2                    29221       09-01-2004  Scholastic Inc.
# 4                      244       11-01-2003       Scholastic
# 5                    36325       05-01-2004  Scholastic Inc.
# 8                      164        9/13/2004       Scholastic
# ...                    ...              ...              ...
# 45631                   20       12/21/2004    Da Capo Press
# 45633                   56       12-01-1988    Penguin Books
# 45634                   95       08-01-1993    Penguin Books
# 45639                  139        2/27/2007             Ecco
# 45641                   12        5/28/2006    Edimat Libros
#
# [11123 rows x 11 columns]

# %% [markdown]
# # most popular books

# %%
books_df['average_rating']=pd.to_numeric(books_df['average_rating'])
books_df[(books_df['average_rating']>4) &(books_df['ratings_count']>10000)]
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 6          10       Harry Potter Collection (Harry Potter  #1-6)
# ...       ...                                                ...
# 10992   45102             Ship of Destiny (Liveship Traders  #3)
# 10994   45112             Assassin's Quest (Farseer Trilogy  #3)
# 11005   45169              Step on a Crack (Michael Bennett  #1)
# 11024   45252                                     Pandora's Star
# 11097   45546  Undaunted Courage: The Pioneering First Missio...
#
#                                 authors  average_rating        isbn  \
# 0            J.K. Rowling/Mary GrandPré            4.57   439785960
# 1            J.K. Rowling/Mary GrandPré            4.49   439358078
# 3            J.K. Rowling/Mary GrandPré            4.56  043965548X
# 4            J.K. Rowling/Mary GrandPré            4.78   439682584
# 6                          J.K. Rowling            4.73   439827604
# ...                                 ...             ...         ...
# 10992                        Robin Hobb            4.22   553575651
# 10994                        Robin Hobb            4.18   553565699
# 11005  James Patterson/Michael Ledwidge            4.01   316013943
# 11024                 Peter F. Hamilton            4.24   345461622
# 11097                Stephen E. Ambrose            4.21  074347788X
#
#              isbn13 language_code    num_pages  ratings_count  \
# 0      9.780000e+12           eng          652        2095690
# 1      9.780000e+12           eng          870        2153167
# 3      9.780000e+12           eng          435        2339585
# 4      9.780000e+12           eng         2690          41428
# 6      9.780000e+12           eng         3342          28242
# ...             ...           ...          ...            ...
# 10992  9.780000e+12           eng          789          46646
# 10994  9.780000e+12           eng          757          67473
# 11005  9.780000e+12           eng          383          37552
# 11024  9.780000e+12           eng          768          33987
# 11097  9.780000e+12           eng          592          41236
#
#        text_reviews_count publication_date                 publisher
# 0                   27591        9-16-2006           Scholastic Inc.
# 1                   29221       09-01-2004           Scholastic Inc.
# 3                   36325       05-01-2004           Scholastic Inc.
# 4                     164        9-13-2004                Scholastic
# 6                     808       09-12-2005                Scholastic
# ...                   ...              ...                       ...
# 10992                1014       11-27-2001             Spectra Books
# 10994                1967       01-05-1998                   Spectra
# 11005                1592       02-06-2007  Little Brown and Company
# 11024                1519       03-02-2005                   Del Rey
# 11097                1830       10-06-2003          Simon & Schuster
#
# [944 rows x 12 columns]

# %% [markdown]
# # pages with lower count

# %%
books_df[(books_df['average_rating']>4) &(books_df['  num_pages']<200)]
# Out:
#        bookID                                              title  \
# 10         16  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 31         54                      Molly Hatchet - 5 of the Best
# 35         59                                 The Changeling Sea
# 46         76                          Heirs of General Practice
# 57         91  Always Enough: God's Miraculous Provision Amon...
# ...       ...                                                ...
# 11102   45570                                   Fantastic Mr Fox
# 11103   45572                 Fantastic Mr. Fox (Cover to Cover)
# 11112   45616       A Última Batalha (As Crónicas de Nárnia  #7)
# 11114   45623   O Sobrinho do Mágico (As Crónicas de Nárnia  #1)
# 11115   45625  A Viagem do Caminheiro da Alvorada (As Crónica...
#
#                                            authors  average_rating  \
# 10                       Douglas Adams/Stephen Fry            4.22
# 31                                   Molly Hatchet            4.33
# 35                            Patricia A. McKillip            4.06
# 46                                     John McPhee            4.17
# 57                       Heidi Baker/Rolland Baker            4.46
# ...                                            ...             ...
# 11102                        David Wood/Roald Dahl            4.09
# 11103                                   Roald Dahl            4.05
# 11112  C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.03
# 11114  C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.04
# 11115  C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.09
#
#              isbn        isbn13 language_code    num_pages  ratings_count  \
# 10      739322206  9.780000e+12           eng            6           1266
# 31     1575606240  9.780000e+12           eng           56              6
# 35      141312629  9.780000e+12           eng          137           4454
# 46      374519749  9.780000e+12           eng          128            268
# 57      800793617  9.780000e+12           eng          192            860
# ...           ...           ...           ...          ...            ...
# 11102  057305133X  9.780000e+12         en-GB           74             65
# 11103  1855495090  9.780000e+12           eng           90              7
# 11112  9722332201  9.790000e+12           por          149            211
# 11114  9722329987  9.790000e+12           por          147            396
# 11115  9722331329  9.790000e+12           por          176            161
#
#        text_reviews_count publication_date                  publisher
# 10                    253        3-23-2005         Random House Audio
# 31                      0       06-10-2003  Cherry Lane Music Company
# 35                    302        4-14-2003                   Firebird
# 46                     22       04-01-1986  Farrar  Straus and Giroux
# 57                     53       09-01-2003               Chosen Books
# ...                   ...              ...                        ...
# 11102                   2       01-05-2011          Samuel French Ltd
# 11103                   0        9-15-1995             BBC Audiobooks
# 11112                  24        7-17-2004         Editorial Presença
# 11114                  37       04-08-2003         Editorial Presença
# 11115                  14       09-01-2004         Editorial Presença
#
# [1243 rows x 12 columns]

# %% [markdown]
# # pages with more number

# %%
books_df[(books_df['  num_pages']>800)]
# Out:
#        bookID                                              title  \
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 6          10       Harry Potter Collection (Harry Potter  #1-6)
# 7          12  The Ultimate Hitchhiker's Guide: Five Complete...
# 8          13  The Ultimate Hitchhiker's Guide to the Galaxy ...
# ...       ...                                                ...
# 11023   45251            Judas Unchained (Commonwealth Saga  #2)
# 11030   45280                Quicksilver (The Baroque Cycle  #1)
# 11081   45486      His Dark Materials (His Dark Materials  #1-3)
# 11083   45490    His Dark Materials Omnibus (His Dark Materials)
# 11110   45607                             Las Crónicas de Narnia
#
#                                                  authors  average_rating  \
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 4                             J.K. Rowling/Mary GrandPré            4.78
# 6                                           J.K. Rowling            4.73
# 7                                          Douglas Adams            4.38
# 8                                          Douglas Adams            4.38
# ...                                                  ...             ...
# 11023                                  Peter F. Hamilton            4.31
# 11030                                    Neal Stephenson            3.93
# 11081                                     Philip Pullman            4.26
# 11083                                     Philip Pullman            4.26
# 11110  C.S. Lewis/Margarita E. Valdes/Gemma Gallart/P...            4.26
#
#             isbn        isbn13 language_code    num_pages  ratings_count  \
# 1      439358078  9.780000e+12           eng          870        2153167
# 4      439682584  9.780000e+12           eng         2690          41428
# 6      439827604  9.780000e+12           eng         3342          28242
# 7      517226952  9.780000e+12           eng          815           3628
# 8      345453743  9.780000e+12           eng          815         249558
# ...          ...           ...           ...          ...            ...
# 11023  345461673  9.780000e+12         en-US         1008            738
# 11030  434008176  9.780000e+12           eng          927            171
# 11081  375847227  9.780000e+12           eng          933           2656
# 11083  375947221  9.780000e+12           eng          944             70
# 11110   61199001  9.780000e+12           spa          816            186
#
#        text_reviews_count publication_date                      publisher
# 1                   29221       09-01-2004                Scholastic Inc.
# 4                     164        9-13-2004                     Scholastic
# 6                     808       09-12-2005                     Scholastic
# 7                     254       11-01-2005                 Gramercy Books
# 8                    4080        4-30-2002                  Del Rey Books
# ...                   ...              ...                            ...
# 11023                  68        3-27-2007                        Del Rey
# 11030                  12       10-02-2003              William Heinemann
# 11081                 260       04-10-2007                Alfred A. Knopf
# 11083                   9       04-10-2007  Knopf Books for Young Readers
# 11110                  11       11-07-2006          HarperCollins Espanol
#
# [431 rows x 12 columns]

# %% [markdown]
# # yes pages with less number having higher ratings are more than books having large number of pages

# %% [markdown]
# # most popular book of 60s

# %%
books_df['publication_date']=pd.to_datetime(books_df['publication_date'],format='%m-%d-%Y',errors='coerce')
books_df[((books_df['publication_date'] >= '01-01-1960') & (books_df['publication_date'] <= '12-31-1969')) & (books_df['average_rating']>4)&(books_df['ratings_count']>5000)]
# Out:
# Empty DataFrame
# Columns: [bookID, title, authors, average_rating, isbn, isbn13, language_code,   num_pages, ratings_count, text_reviews_count, publication_date, publisher]
# Index: []

# %% [markdown]
# # most pages

# %%
books_df['  num_pages'].max()
# Out:
# 6576

# %% [markdown]
# # the average or the mean count of page of author books is 336

# %%
books_df['  num_pages'].mean()
# Out:
# 336.4055560550211

# %% [markdown]
# # books with lesss than 200  pages

# %%
books_df[(books_df['  num_pages']<200)]
# Out:
#        bookID                                              title  \
# 5           9  Unauthorized Harry Potter Book Seven News: "Ha...
# 10         16  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 13         22                        Bill Bryson's African Diary
# 29         51  Hatchet: A Guide for Using "Hatchet" in the Cl...
# 30         53  Guts: The True Stories behind Hatchet and the ...
# ...       ...                                                ...
# 11113   45617  O Cavalo e o Seu Rapaz (As Crónicas de Nárnia ...
# 11114   45623   O Sobrinho do Mágico (As Crónicas de Nárnia  #1)
# 11115   45625  A Viagem do Caminheiro da Alvorada (As Crónica...
# 11116   45626     O Príncipe Caspian (As Crónicas de Nárnia  #4)
# 11117   45630                                  Whores for Gloria
#
#                                               authors  average_rating  \
# 5                              W. Frederick Zimmerman            3.74
# 10                          Douglas Adams/Stephen Fry            4.22
# 13                                        Bill Bryson            3.44
# 29     Donna Ickes/Edward Sciranko/Keith Vasconcelles            4.00
# 30                                       Gary Paulsen            3.88
# ...                                               ...             ...
# 11113     C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            3.92
# 11114     C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.04
# 11115     C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.09
# 11116     C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            3.97
# 11117                             William T. Vollmann            3.69
#
#              isbn        isbn13 language_code    num_pages  ratings_count  \
# 5       976540606  9.780000e+12         en-US          152             19
# 10      739322206  9.780000e+12           eng            6           1266
# 13      767915062  9.780000e+12           eng           55           7270
# 29     1557344493  9.780000e+12           eng           48             36
# 30      385326505  9.780000e+12           eng          144           2067
# ...           ...           ...           ...          ...            ...
# 11113  9722330551  9.790000e+12           por          160            207
# 11114  9722329987  9.790000e+12           por          147            396
# 11115  9722331329  9.790000e+12           por          176            161
# 11116  9722330977  9.790000e+12           por          160            215
# 11117   140231579  9.780000e+12         en-US          160            932
#
#        text_reviews_count publication_date                  publisher
# 5                       1       2005-04-26               Nimble Books
# 10                    253       2005-03-23         Random House Audio
# 13                    499       2002-12-03             Broadway Books
# 29                      2       1994-08-28  Teacher Created Resources
# 30                    334       2001-01-23            Delacorte Press
# ...                   ...              ...                        ...
# 11113                  16       2003-08-15         Editorial Presença
# 11114                  37       2003-04-08         Editorial Presença
# 11115                  14       2004-09-01         Editorial Presença
# 11116                  11       2003-10-11         Editorial Presença
# 11117                 111       1994-02-01              Penguin Books
#
# [2897 rows x 12 columns]

# %% [markdown]
#  # Houghton Mifflin Harcourt's most popular book

# %%
books_df[(books_df['publisher']=='Houghton Mifflin Harcourt') & (books_df['average_rating']>4) & (books_df['ratings_count']>20000)]
# Out:
#       bookID                                              title  \
# 23        34  The Fellowship of the Ring (The Lord of the Ri...
# 72       119  The Lord of the Rings: The Art of the Fellowsh...
# 1579    5439                            Interpreter of Maladies
# 1585    5472                                 Animal Farm / 1984
#
#                                  authors  average_rating       isbn  \
# 23                        J.R.R. Tolkien            4.36  618346252
# 72                          Gary Russell            4.59  618212906
# 1579                       Jhumpa Lahiri            4.15  618101365
# 1585  George Orwell/Christopher Hitchens            4.28  151010269
#
#             isbn13 language_code    num_pages  ratings_count  \
# 23    9.780000e+12           eng          398        2128944
# 72    9.780000e+12           eng          192          26153
# 1579  9.780000e+12           eng          198         131876
# 1585  9.780000e+12           eng          400         146659
#
#       text_reviews_count publication_date                  publisher
# 23                 13670       2003-09-05  Houghton Mifflin Harcourt
# 72                   102       2002-06-12  Houghton Mifflin Harcourt
# 1579                8009       2000-05-22  Houghton Mifflin Harcourt
# 1585                1625       2003-06-01  Houghton Mifflin Harcourt

# %%
book_author=books_df[['title','authors','average_rating','ratings_count']].copy()

# %%
book_author
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Chamber of Secrets (Harry...
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                  ...
# 11118   Expelled from Eden: A William T. Vollmann Reader
# 11119                        You Bright and Risen Angels
# 11120                    The Ice-Shirt (Seven Dreams #1)
# 11121                                        Poor People
# 11122                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#        ratings_count
# 0            2095690
# 1            2153167
# 2               6333
# 3            2339585
# 4              41428
# ...              ...
# 11118            156
# 11119            783
# 11120            820
# 11121            769
# 11122            113
#
# [11123 rows x 4 columns]

# %%
book_author[((book_author['average_rating'])>(book_author['average_rating'].mean())) &((book_author['ratings_count'])>(book_author['ratings_count'].mean()))]
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 6           Harry Potter Collection (Harry Potter  #1-6)
# ...                                                  ...
# 10992             Ship of Destiny (Liveship Traders  #3)
# 10994             Assassin's Quest (Farseer Trilogy  #3)
# 11005              Step on a Crack (Michael Bennett  #1)
# 11024                                     Pandora's Star
# 11097  Undaunted Courage: The Pioneering First Missio...
#
#                                 authors  average_rating  ratings_count
# 0            J.K. Rowling/Mary GrandPré            4.57        2095690
# 1            J.K. Rowling/Mary GrandPré            4.49        2153167
# 3            J.K. Rowling/Mary GrandPré            4.56        2339585
# 4            J.K. Rowling/Mary GrandPré            4.78          41428
# 6                          J.K. Rowling            4.73          28242
# ...                                 ...             ...            ...
# 10992                        Robin Hobb            4.22          46646
# 10994                        Robin Hobb            4.18          67473
# 11005  James Patterson/Michael Ledwidge            4.01          37552
# 11024                 Peter F. Hamilton            4.24          33987
# 11097                Stephen E. Ambrose            4.21          41236
#
# [874 rows x 4 columns]

# %% [markdown]
# # least popular of 90s

# %%
books_df[ (books_df['average_rating']<2.5)&(books_df['ratings_count']<1000)]
# Out:
#        bookID                                              title  \
# 265       799  Out to Eat London 2002 (Lonely Planet Out to Eat)
# 375      1302                     Juiced Official Strategy Guide
# 987      3351           Open City 6: The Only Woman He Ever Left
# 1681     5863                                       V.S. Naipaul
# 2532     9337  How To Meditate: An Anthology Of Talks On Medi...
# 2533     9338         Insights: Talks On The Nature Of Existence
# 2758    10200                Venac sonetnih venaca; Puževa srma
# 3234    11854           Puzzle Pack: The Witch of Blackbird Pond
# 3492    12712  Brodie's notes on Aldous Huxley's brave new world
# 3912    13964  The Boys of the Archangel Raphael: A Youth Con...
# 4241    15186                                American Film Guide
# 4677    16806  The Man and the Author: John Milton: Twentieth...
# 5323    19257  Canopy: A Work for Voice and Light in Harvard ...
# 5537    20157  McDougal Littell Science: Student Edition Grad...
# 5670    21107  The Halloween Activity Book: Creepy  Crawly  H...
# 6380    24010         Laguna  I Love You: The Best of "Our Town"
# 6558    24749                  American Writers  Supplement VIII
# 6839    25780               The Two Tocquevilles  Father and Son
# 6859    25841                           The Road To War  1933 39
# 6877    25903  I'll Be Home Before Midnight and I Won't Get P...
# 7144    27416  Mythographi Graeci 1: Apollodori Bibliotheca  ...
# 7399    28467                   Sclerotherapy and vein treatment
# 7573    29091                           The Berlin Phenomenology
# 7634    29404       Your Child and Jesus: A Family Activity Book
# 7797    30080                  Beckett Football Card Price Guide
# 7998    30651  The Art of Loving by Erich Fromm: A True Story...
# 8109    31166  The Earth and Its Peoples: A Global History  V...
# 9331    36946      Random House Crossword Mega Omnibus  Volume 1
# 9437    37467  Classroom Interactions as Cross-Cultural Encou...
# 9539    37877                               Mandala Sand Art Kit
# 10138   41044                                      Day and Night
# 10497   42758  The Fantastic Vampire: Studies in the Children...
# 10917   44705  The Leadership Challenge: Skills for Taking Ch...
# 11027   45259  Anthony Thwaite: In Conversation With Peter Da...
# 11091   45516             The Die Broke Financial Problem Solver
#
#                                                  authors  average_rating  \
# 265                             Lonely Planet/Mark Honan            0.00
# 375                                           Doug Walsh            0.00
# 987    Open City Magazine/James Purdy/Daniel Pinchbec...            0.00
# 1681                                    Bruce Alvin King            2.00
# 2532                                   Frederick P. Lenz            0.00
# 2533                                   Frederick P. Lenz            0.00
# 2758                                        Dobrica Erić            0.00
# 3234                                     Mary B. Collins            1.00
# 3492                                      Graham Handley            0.00
# 3912                                 Konrad Eisenbichler            2.00
# 4241                                     Frank N. Magill            0.00
# 4677                                     J. Martin Evans            0.00
# 5323   David   Ward/Parveen Adams/Seamus Heaney/Ivan ...            0.00
# 5537                 McDougal Littell/Douglas W. Carnine            2.00
# 5670                          Mymi Doinet/Benjamin Chaud            2.00
# 6380                           John Weld/Phil Interlandi            0.00
# 6558                            Jay Parini/August Wilson            0.00
# 6839                                         R.R. Palmer            2.00
# 6859                                    Andrew      Hunt            0.00
# 6877                                     Anthony E. Wolf            0.00
# 7144                          Apollodorus/Richard Wagner            0.00
# 7399   Robert A. Weiss/Margaret A. Weiss/Karen L. Bea...            0.00
# 7573    Georg Wilhelm Friedrich Hegel/Michael John Petry            0.00
# 7634                           Rick Osborne/Kevin Miller            0.00
# 7797                          Dan Hitt/James Beckett III            0.00
# 7998                                        Lala Okamoto            1.67
# 8109   Richard W. Bulliet/Pamela Kyle Crossley/Steven...            2.00
# 9331                          United Feature Syndication            0.00
# 9437                     Jasmine C.M. Luk/Angel M.Y. Lin            0.00
# 9539                         Walter Foster Creative Team            1.00
# 10138                           Better Homes and Gardens            0.00
# 10497                                  James Craig Holte            0.00
# 10917                                   Warren G. Bennis            0.00
# 11027  Peter  Dale/Ian          Hamilton/Anthony Thwaite            0.00
# 11091                      Stephen M. Pollan/Mark LeVine            2.33
#
#              isbn        isbn13 language_code    num_pages  ratings_count  \
# 265    1740592050  9.780000e+12           eng          295              0
# 375     744005612  9.780000e+12           eng          112              0
# 987    189044717X  9.780000e+12           eng          200              0
# 1681   1403904561  9.780000e+12           eng          240              0
# 2532   1932206108  9.780000e+12           eng          228              0
# 2533   1932206086  9.780000e+12           eng          304              0
# 2758   8644101277  9.790000e+12           srp          222              0
# 3234   1583377824  9.780000e+12           eng          134              2
# 3492    333581296  9.780000e+12           eng           71              0
# 3912    802043291  9.780000e+12           eng          498              1
# 4241    893562505  9.780000e+12           eng            5              0
# 4677    415940478  9.780000e+12           eng          386              0
# 5323    916724948  9.780000e+12           eng           63              0
# 5537    618615385  9.780000e+12           eng          972              3
# 5670    811832791  9.780000e+12           eng           32              1
# 6380   1564741575  9.780000e+12           eng          285              0
# 6558    684806371  9.780000e+12           eng          400              0
# 6839    691054959  9.780000e+12           eng          254              1
# 6859    340774770  9.780000e+12           eng          128              0
# 6877    394755669  9.780000e+12           eng          288              0
# 7144   3598715439  9.780000e+12           grc          335              0
# 7399     71485422  9.780000e+12           eng          248              0
# 7573   9027712050  9.790000e+12           eng          210              0
# 7634   080242855X  9.780000e+12           eng          112              0
# 7797   1930692471  9.780000e+12           eng          830              0
# 7998   4990327500  9.780000e+12           eng          227              3
# 8109    618427694  9.780000e+12           eng          370              1
# 9331   081292763X  9.780000e+12           eng          336              0
# 9437    805850848  9.780000e+12           eng          241              0
# 9539   1560107669  9.780000e+12           eng            8              1
# 10138   696018829  9.780000e+12           eng           32              0
# 10497   313309337  9.780000e+12           eng          176              0
# 10917  088684049X  9.780000e+12           eng           60              0
# 11027   953284123  9.780000e+12           eng           96              0
# 11091    66619912  9.780000e+12         en-US          272              3
#
#        text_reviews_count publication_date  \
# 265                     0       2001-09-01
# 375                     0       2005-06-01
# 987                     0       2000-10-13
# 1681                    0       2003-10-10
# 2532                    0       2004-01-01
# 2533                    0       2003-01-01
# 2758                    0       1996-01-01
# 3234                    0       2005-08-15
# 3492                    0       1992-08-20
# 3912                    0       1998-05-30
# 4241                    0       1983-01-01
# 4677                    0       2002-11-08
# 5323                    0       1997-12-31
# 5537                    0       2005-04-12
# 5670                    1       2002-08-01
# 6380                    0       1996-03-01
# 6558                    0       2001-05-01
# 6839                    0       1987-04-01
# 6859                    0       2000-04-01
# 6877                    0       1988-05-12
# 7144                    0       1998-07-15
# 7399                    0       2011-12-30
# 7573                    0       1981-05-31
# 7634                    0       1999-09-13
# 7797                    0       2006-09-01
# 7998                    2       2006-10-31
# 8109                    1       2004-02-09
# 9331                    0       1997-07-22
# 9437                    0       2006-08-05
# 9539                    0       2004-01-01
# 10138                   1       1989-03-01
# 10497                   0       2002-03-30
# 10917                   0       1985-12-01
# 11027                   0       1999-12-09
# 11091                   0       2000-12-26
#
#                                                publisher
# 265                                        Lonely Planet
# 375                                           BradyGames
# 987                         Grove Press  Open City Books
# 1681                                  Palgrave Macmillan
# 2532   Frederick P. Lenz Foundation for American Budd...
# 2533   Frederick P. Lenz Foundation for American Budd...
# 2758                      Izdavačka agencija "Draganić"
# 3234                    Teacher's Pet Publications  Inc.
# 3492                                           Macmillan
# 3912                         University of Toronto Press
# 4241                                     Salem Press Inc
# 4677                                           Routledge
# 5323                                   Arts Publications
# 5537                                     McDougal Littel
# 5670                                     Chronicle Books
# 6380                                       Fithian Press
# 6558                                        Gale Cengage
# 6839                          Princeton University Press
# 6859             Hodder & Stoughton Educational Division
# 6877                    Knopf Doubleday Publishing Group
# 7144                                    K.G. Saur Verlag
# 7399                 McGraw-Hill Professional Publishing
# 7573                                            Springer
# 7634                                    Moody Publishers
# 7797                                       Beckett Media
# 7998                            Intercultural Publishing
# 8109                                    Cengage Learning
# 9331                        Random House Puzzles & Games
# 9437                                           Routledge
# 9539                            Walter Foster Publishing
# 10138                               Meredith Corporation
# 10497                                    Greenwood Press
# 10917                    AMR/Advanced Management Reports
# 11027                      Between the Lines Productions
# 11091                          William Morrow Paperbacks

# %% [markdown]
# # highest rated book with more than 500 pages

# %%
books_df[ (books_df['average_rating']>4.5)&(books_df['ratings_count']>100000) &(books_df['  num_pages']>500) & (books_df['text_reviews_count']>books_df['text_reviews_count'].mean())]
# Out:
#     bookID                                              title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 21      30  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
#
#                        authors  average_rating       isbn        isbn13  \
# 0   J.K. Rowling/Mary GrandPré            4.57  439785960  9.780000e+12
# 21              J.R.R. Tolkien            4.59  345538374  9.780000e+12
#
#    language_code    num_pages  ratings_count  text_reviews_count  \
# 0            eng          652        2095690               27591
# 21           eng         1728         101233                1550
#
#    publication_date         publisher
# 0        2006-09-16   Scholastic Inc.
# 21       2012-09-25  Ballantine Books
